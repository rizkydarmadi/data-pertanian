# %%
# import data
import pandas as pd

top_provinsi = pd.read_csv('dataset/top_provinsi_2000-2021.csv')
top_provinsi
# Out:
#                 provinsi      total
# 0       KALIMANTAN UTARA     254108
# 1         SULAWESI BARAT     256593
# 2           MALUKU UTARA     340443
# 3            PAPUA BARAT     388700
# 4              GORONTALO     398372
# 5                 MALUKU     432479
# 6              KEP. RIAU     476924
# 7            DKI JAKARTA     477314
# 8   KEP. BANGKA BELITUNG     568412
# 9      SULAWESI TENGGARA     943680
# 10                 PAPUA     946713
# 11     KALIMANTAN TENGAH     983010
# 12      KALIMANTAN BARAT    1430396
# 13       SULAWESI TENGAH    1643454
# 14   NUSA TENGGARA TIMUR    1678707
# 15    KALIMANTAN SELATAN    1994257
# 16      KALIMANTAN TIMUR    2554673
# 17                  RIAU    2826127
# 18                BANTEN    3727435
# 19      SUMATERA SELATAN    3776149
# 20                  ACEH    4734277
# 21                 JAMBI    5093387
# 22                  BALI    5606617
# 23               LAMPUNG    5742841
# 24   NUSA TENGGARA BARAT    6123119
# ...

# %%
df = pd.DataFrame({
        'provinsi': top_provinsi['provinsi'].values,
        'values':top_provinsi['total'].values
    })
ax = df.plot.barh(x='provinsi',y='values')
# Out:
# ['KALIMANTAN UTARA' 'SULAWESI BARAT' 'MALUKU UTARA' 'PAPUA BARAT'
#  'GORONTALO' 'MALUKU' 'KEP. RIAU' 'DKI JAKARTA' 'KEP. BANGKA BELITUNG'
#  'SULAWESI TENGGARA' 'PAPUA' 'KALIMANTAN TENGAH' 'KALIMANTAN BARAT'
#  'SULAWESI TENGAH' 'NUSA TENGGARA TIMUR' 'KALIMANTAN SELATAN'
#  'KALIMANTAN TIMUR' 'RIAU' 'BANTEN' 'SUMATERA SELATAN' 'ACEH' 'JAMBI'
#  'BALI' 'LAMPUNG' 'NUSA TENGGARA BARAT' 'SULAWESI UTARA' 'DI YOGYAKARTA'
#  'BENGKULU' 'SULAWESI SELATAN' 'SUMATERA BARAT' 'SUMATERA UTARA'
#  'JAWA TENGAH' 'JAWA TIMUR' 'JAWA BARAT']

# %%
import matplotlib.pyplot as plt
provinsi = top_provinsi['provinsi'].values
total = top_provinsi['total'].values

plt.barh(provinsi,total)
# plt.title('Store Inventory')
# plt.ylabel('Product')
# plt.xlabel('Quantity')
plt.show()
